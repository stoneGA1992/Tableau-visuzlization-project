# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
april2018 = pd.read_csv('April_2018.csv')
april2019 = pd.read_csv('April_2019.csv')
april2020 = pd.read_csv('April_2020.csv')

# %%
april2018
# Out:
#        tripduration starttime stoptime  start station id start station name  \
# 0               329   37:37.0  43:06.6              3183     Exchange Place
# 1               118   37:30.1  39:28.4              3183     Exchange Place
# 2                76   26:17.9  27:34.7              3183     Exchange Place
# 3               578   10:36.2  20:14.9              3183     Exchange Place
# 4               485   21:47.9  29:53.3              3183     Exchange Place
# ...             ...       ...      ...               ...                ...
# 17104           239   24:17.9  28:17.8              3640     Journal Square
# 17105           364   45:26.5  51:31.5              3640     Journal Square
# 17106           336   38:32.7  44:09.1              3640     Journal Square
# 17107           194   08:09.5  11:23.7              3640     Journal Square
# 17108           290   54:45.1  59:35.4              3640     Journal Square
#
# ...

# %%
#Add the Year and month columns to 2018
april2018 = april2018.assign(year = '2018')
april2018 = april2018.assign(month = 'April')
april2018
# Out:
#        tripduration starttime stoptime  start station id start station name  \
# 0               329   37:37.0  43:06.6              3183     Exchange Place
# 1               118   37:30.1  39:28.4              3183     Exchange Place
# 2                76   26:17.9  27:34.7              3183     Exchange Place
# 3               578   10:36.2  20:14.9              3183     Exchange Place
# 4               485   21:47.9  29:53.3              3183     Exchange Place
# ...             ...       ...      ...               ...                ...
# 17104           239   24:17.9  28:17.8              3640     Journal Square
# 17105           364   45:26.5  51:31.5              3640     Journal Square
# 17106           336   38:32.7  44:09.1              3640     Journal Square
# 17107           194   08:09.5  11:23.7              3640     Journal Square
# 17108           290   54:45.1  59:35.4              3640     Journal Square
#
# ...

# %%
#Add the Year and month columns to 2019
april2019 = april2019.assign(year = '2019')
april2019 = april2019.assign(month = 'April')
april2019
# Out:
#        tripduration starttime stoptime  start station id start station name  \
# 0               306   47:08.2  52:14.7              3183     Exchange Place
# 1               123   30:53.0  32:56.8              3183     Exchange Place
# 2               328   18:30.4  23:59.1              3183     Exchange Place
# 3                95   04:47.2  06:22.8              3183     Exchange Place
# 4               169   51:29.4  54:19.2              3183     Exchange Place
# ...             ...       ...      ...               ...                ...
# 23601           916   38:36.2  53:53.0              3694     Jackson Square
# 23602           661   29:18.8  40:20.3              3694     Jackson Square
# 23603           577   43:09.2  52:46.7              3694     Jackson Square
# 23604           585   33:21.5  43:06.8              3694     Jackson Square
# 23605           914   59:32.4  14:46.8              3694     Jackson Square
#
# ...

# %%
#Add the Year and month columns to 2020
april2020 = april2020.assign(year = '2020')
april2020 = april2020.assign(month = 'April')
april2020
# Out:
#        tripduration starttime stoptime  start station id start station name  \
# 0               389   14:07.0  20:36.1              3202       Newport PATH
# 1               242   48:06.4  52:09.0              3185          City Hall
# 2               124   08:46.5  10:51.3              3272       Jersey & 3rd
# 3               104   22:35.5  24:20.2              3202       Newport PATH
# 4               228   39:20.3  43:09.1              3194    McGinley Square
# ...             ...       ...      ...               ...                ...
# 17714           296   50:39.0  55:35.6              3191           Union St
# 17715           147   09:16.0  11:43.5              3640     Journal Square
# 17716           364   17:02.0  23:06.8              3195            Sip Ave
# 17717          1217   36:10.6  56:27.8              3267       Morris Canal
# 17718           846   37:21.2  51:28.1              3195            Sip Ave
#
# ...

# %%
#Combine all into one spreadsheet

combined_data = april2018.append([april2019, april2020], ignore_index = True)

combined_data
# Out:
#        tripduration starttime stoptime  start station id start station name  \
# 0               329   37:37.0  43:06.6              3183     Exchange Place
# 1               118   37:30.1  39:28.4              3183     Exchange Place
# 2                76   26:17.9  27:34.7              3183     Exchange Place
# 3               578   10:36.2  20:14.9              3183     Exchange Place
# 4               485   21:47.9  29:53.3              3183     Exchange Place
# ...             ...       ...      ...               ...                ...
# 58429           296   50:39.0  55:35.6              3191           Union St
# 58430           147   09:16.0  11:43.5              3640     Journal Square
# 58431           364   17:02.0  23:06.8              3195            Sip Ave
# 58432          1217   36:10.6  56:27.8              3267       Morris Canal
# 58433           846   37:21.2  51:28.1              3195            Sip Ave
#
# ...
